# %%
#!git clone https://github.com/theschoolofai/YoloV3.git
# !git clone https://github.com/vigneshbabupj/EVA5
# Out:
# Cloning into 'EVA5'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 127958 (delta 39), reused 83 (delta 26), pack-reused 127853
# Receiving objects: 100% (127958/127958), 479.82 MiB | 40.60 MiB/s, done.
# Resolving deltas: 100% (1288/1288), done.
# Checking out files: 100% (127911/127911), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
cd /content/EVA5/S13/Part B/YoloV3-master/
# Out:
# /content/EVA5/S13/Part B/YoloV3-master

# %%
# !mkdir weights

# %%
# !cp "/content/gdrive/My Drive/EVA5/S13/B/yolov3-spp-ultralytics.pt" "/content/EVA5/S13/Part B/YoloV3-master/weights/"

# %%
# !cp "/content/gdrive/My Drive/EVA5/S13/B/weights/last.pt" "/content/EVA5/S13/Part B/YoloV3-master/weights/"

# %%
ls
# Out:
#  cfg/        README.md         test.py            utils/
#  data/       results.json      ting               vim.exe.stackdump
#  detect.py   results.png       train_batch0.png   weights/
#  models.py   results.txt       train.py
#  output/     test_batch0.png  'ubdivisions=1'

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=100, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-24 04:07:04.077735: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2863 found, 131 missing, 38 empty, 0 duplicate, for 3032 images): 100% 3032/3032 [00:01<00:00, 2327.92it/s]
# Caching images (1.7GB): 100% 3032/3032 [00:19<00:00, 159.31it/s]
# ...

# %%
# !cp "/content/EVA5/S13/Part B/YoloV3-master/weights/last.pt" "/content/gdrive/My Drive/EVA5/S13/B/weights"

# %%
#!python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave

# %%
# !python detect.py --conf-thres 0.1 --output "/content/gdrive/My Drive/EVA5/S13/B/output_new" --source "/content/gdrive/My Drive/EVA5/S13/B/Video_new"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/EVA5/S13/B/output_new', save_txt=False, source='/content/gdrive/My Drive/EVA5/S13/B/Video_new', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# video 1/1 (1/2688) /content/gdrive/My Drive/EVA5/S13/B/Video_new/Worker_Video.mp4: 320x512 3 hardhats, 2 vests, 1 bootss, Done. (0.033s)
# video 1/1 (2/2688) /content/gdrive/My Drive/EVA5/S13/B/Video_new/Worker_Video.mp4: 320x512 3 hardhats, 2 vests, 1 bootss, Done. (0.033s)
# video 1/1 (3/2688) /content/gdrive/My Drive/EVA5/S13/B/Video_new/Worker_Video.mp4: 320x512 3 hardhats, 2 vests, 2 bootss, Done. (0.033s)
# ...

# %%
# !ls
# Out:
#  cfg	     __pycache__    runs	       train.py
#  data	     README.md	    test_batch0.png   'ubdivisions=1'
#  detect.py   results.json   test.py	       utils
#  models.py   results.png    ting	       vim.exe.stackdump
#  output      results.txt    train_batch0.png   weights

# %%
Image(filename='/content/gdrive/My Drive/EVA5/S13/B/out/image-250.jpg', width=600)

# %%
Image(filename='/content/gdrive/My Drive/EVA5/S13/B/out/image-619.jpg', width=600)

# %%
Image(filename='/content/gdrive/My Drive/EVA5/S13/B/out/image-001.jpg', width=600)
